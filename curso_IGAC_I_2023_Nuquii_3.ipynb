# %% [markdown]
# <a href="https://colab.research.google.com/github/monteroanibal/curso_IGAC_I_2023/blob/main/curso_IGAC_I_2023_Nuquii_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <figure>
# <center>
# <img src='https://upload.wikimedia.org/wikipedia/commons/e/ee/IGAC_%28Colombia%29_logo.png', height="75">
# <figcaption>Instituto Geográfico Agustín Codazzi - IGAC<br> Dirección de Investigación y Prospectiva - DIP</figcaption></center>
# </figure>

# %% [markdown]
# ---
# ---

# %% [markdown]
# ***SESIÓN (#):<br> EXPLORACIÓN Y PREPROCESAMIENTO DE INFORMACIÓN ESPACIAL***

# %% [markdown]
# En esta sesión de trabajo, usted alcanzará los siguientes objetivos:
#
# 1. Aprender a realizar alistamiento de los posibles entornos de programación  de acuerdo a las librerias y extensiones que sea pertinentes para su procesamiento.
# 2.Aprender a almacenar, generar enlaces a repositorios e importar los archivos con los que se requiera laborar.
# 3. Aprender a chequear la disponibilidad, lectura y calidad de los datos
# 4. Aprender a explorar los datos en geodataframe a través de su tabla de atributos y sus salidas gráficas
# 5. Aprender a cruzar diferentes  tipos de información
# 6. Aprender a aplicar funciones de geoprocesamiento y preprocesamiento a los insumos
# 7. Aprender a Rasterizar y exportar las salidas gráficas.
# 8. Aprender a realizar calculos y procesamiento con los raster.

# %% [markdown]
# ---
#
# ---

# %% [markdown]
# # Alistamiento del entorno
# ---

# %% [markdown]
# Estas librerías permiten explorar los archivos en el entorno de Colab.

# %%
import glob
import os

# %% [markdown]
# Para importar shapefiles como GeoDataFrames. *Leafmap* para descargar datos de OpenStreetMap.

# %%
# %%capture
# !pip install leafmap
#!pip install geopandas osmnx
# !pip install osmnx

# %%
# %%capture
# !pip install osmnx

# %%
import geopandas as gpd
import leafmap

# %% [markdown]
# Para poner de fondo el contexto de OpenStreetMap.

# %%
# %%capture
# !pip install contextily

# %%
import contextily as ctx

# %% [markdown]
# Paras utilizar los colores en el mapa cloroplético.

# %%
import matplotlib.colors as mcolors
from matplotlib import pyplot as plt

# %% [markdown]
# Para rasterizar capas geométricas.

# %%
from osgeo import gdal, ogr, osr

# %% [markdown]
# Para generar resúmenes estadísticos de los rásters generados.

# %%
import numpy as np

# %% [markdown]
# # Se importan los datos
# ---

# %% [markdown]
# Se descargan los shapefiles que están publicados en un Github y se descomprimen en la sesión actual.

# %%
# %%capture
# !wget https://github.com/tdavila28/curso_IGAC_I_2023/releases/download/inputs/Nuqui_Manual_Python.zip
# !unzip -o /content/Nuqui_Manual_Python.zip
# !rm /content/Nuqui_Manual_Python.zip

# %% [markdown]
# Para este ejemplo, cada shapefile representa una capa de información sobre el municipio de Nuquí. Se organizan las direcciones en orden alfabético.

# %%
ubicacion_shps = glob.glob(os.path.join("/content/Nuqui_Manual_Python/","*.shp"))
ubicacion_shps = sorted(ubicacion_shps)
ubicacion_shps
# Out:
# ['/content/Nuqui_Manual_Python/Amb_Humedal.shp',
#  '/content/Nuqui_Manual_Python/Cent_Pob_nac.shp',
#  '/content/Nuqui_Manual_Python/coberturas_2010_2012.shp',
#  '/content/Nuqui_Manual_Python/comunidades_negras_tituladas.shp',
#  '/content/Nuqui_Manual_Python/nuqui_mpal.shp',
#  '/content/Nuqui_Manual_Python/resguardos_indigenas_legalizado.shp']

# %% [markdown]
# Cada shapefile consta de una tabla, donde cada fila representa un elemento en el espacio y cada columna representa un atributo de ese elemento. Se importan los shapefiles de interés, tomando como referencia la numeración de las direcciones desplegadas anteriormente. La numeración o indexación en Python arranca desde cero (0). Normalente se utiliza en encoding utf-8 para referir a que se están utilizando caracteres propios del idimoa español (letras con acentos).

# %%
nuqui_hume = gpd.read_file( ubicacion_shps[0], encoding='utf-8' ) # Humedales
nuqui_lulc = gpd.read_file( ubicacion_shps[2], encoding='utf-8' ) # Coberturas del suelo
nuqui_area = gpd.read_file( ubicacion_shps[4], encoding='utf-8' ) # Geometriia del municipio de Nuquii

# %% [markdown]
# La siguiente sentencia permite chequear el tipo de objeto al que apunta un nombre asignado.

# %%
type(nuqui_lulc)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# # Chequeo de la importación
# ---

# %% [markdown]
# Una primera aproximación a la revisión de si es ha importado una capa de información de forma correcta es dibujándola mediante el método *plot()* aplicado directamente al objeto GeoDataFrame.

# %%
nuqui_area#.head()
# Out:
#    OBJECTID MpCodigo MpNombre      MpArea MpNorma  MpCategor  MpAltitud  \
# 0      1768    27495    Nuquí  704.583366    None          1          5
#
#                                           Restriccio  Depto     Shape_Leng  \
# 0  “No es apropiada su aplicación para la ubicaci...  Chocó  270334.189583
#
#      Shape_Area                                           geometry
# 0  7.045834e+08  POLYGON ((4525086.301 2223344.371, 4525092.458...

# %%
ax =nuqui_area.plot(column='MpArea',legend=False, cmap='OrRd',facecolor="grey", edgecolor="black")
ax.set_axis_off()

# %% [markdown]
# El siguiente comando despliega el metadato del sistema de coordenadas de referencia sobre el que están proyectados los objetos del shapefile.

# %%
nuqui_area.crs
# Out:
# <Projected CRS: PROJCS["MAGNA-SIRGAS_Origen-Nacional",GEOGCS["MAGN ...>
# Name: MAGNA-SIRGAS_Origen-Nacional
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Transverse Mercator
# Datum: Marco Geocentrico Nacional de Referencia
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %% [markdown]
# Se reproyecta la capa al sistema de coordenadas con código 3857 con el fin de poder utilizar los mapas de fondo de OpenStreetMap.

# %%
nuqui_hume = nuqui_hume.to_crs(epsg=3857)
nuqui_lulc = nuqui_lulc.to_crs(epsg=3857)
nuqui_area = nuqui_area.to_crs(epsg=3857)

# %% [markdown]
# Se chequea de nuevo el nuevo sistema de coordenadas sobre el que se reproyectaron las capas de información.

# %%
nuqui_area.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# A continuación, se muestra la demarcación espacial del municipio de Nuquí y con ayuda del mapa de fondo.

# %%
ax = nuqui_area.boundary.plot(figsize=(5,5), edgecolor='k', alpha=0.25)
nuqui_area.plot(ax=ax, color='#abafae', alpha=1, edgecolor="black")
ax.set_axis_off()
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron)

# %% [markdown]
# Al llamar el nombre de los GeoDataFrames sobre los que se importaron las capas de información, Colab despliega los primeros y últimos registros de las capas de información que sea llamada.

# %%
nuqui_hume
# Out:
#      Nivel_Hume     Area_Ha  Fecha_Ingr Fecha_Reco     NOMAH  \
# 0             2  727.503672  2020-08-28       None  Pacifico
# 1             2    1.590278  2020-08-28       None  Pacifico
# 2             1    0.000721  2020-08-28       None  Pacifico
# 3             1    0.092073  2020-08-28       None  Pacifico
# 4             1    0.132748  2020-08-28       None  Pacifico
# ..          ...         ...         ...        ...       ...
# 443           2    0.802682  2020-08-28       None  Pacifico
# 444           1    1.626985  2020-08-28       None  Pacifico
# 445           1  129.231906  2020-08-28       None  Pacifico
# 446           1    0.000977  2020-08-28       None  Pacifico
# 447           1    0.000032  2020-08-28       None  Pacifico
#
#                    NOMZH                             NOMSZH  \
# 0    Pacífico - Directos  Directos Pacifico Frontera Panamá
# 1    Pacífico - Directos  Directos Pacifico Frontera Panamá
# 2    Pacífico - Directos  Directos Pacifico Frontera Panamá
# 3    Pacífico - Directos  Directos Pacifico Frontera Panamá
# 4    Pacífico - Directos  Directos Pacifico Frontera Panamá
# ..                   ...                                ...
# 443  Pacífico - Directos  Directos Pacifico Frontera Panamá
# 444  Pacífico - Directos  Directos Pacifico Frontera Panamá
# 445  Pacífico - Directos  Directos Pacifico Frontera Panamá
# 446  Pacífico - Directos  Directos Pacifico Frontera Panamá
# 447  Pacífico - Directos  Directos Pacifico Frontera Panamá
#
#             Grado_Tran                                           geometry
# 0              Natural  POLYGON ((-8605258.980 664590.975, -8605258.92...
# 1              Natural  MULTIPOLYGON (((-8604027.708 661085.072, -8604...
# 2                    -  MULTIPOLYGON (((-8601697.467 655698.379, -8601...
# 3                    -  MULTIPOLYGON (((-8601376.298 655497.838, -8601...
# 4                    -  MULTIPOLYGON (((-8601678.268 655772.275, -8601...
# ..                 ...                                                ...
# 443  Sin informacion e  MULTIPOLYGON (((-8614435.802 626600.030, -8614...
# 444                  -  MULTIPOLYGON (((-8611854.981 625137.153, -8611...
# 445                  -  MULTIPOLYGON (((-8604679.686 632619.207, -8604...
# 446                  -  MULTIPOLYGON (((-8602224.933 636138.423, -8602...
# 447                  -  POLYGON ((-8598474.973 645027.800, -8598475.19...
#
# [448 rows x 9 columns]

# %% [markdown]
# La capa *nuqui_area* contiene solo un polígono que delimita el respectivo municipio.

# %%
nuqui_area
# Out:
#    OBJECTID MpCodigo MpNombre      MpArea MpNorma  MpCategor  MpAltitud  \
# 0      1768    27495    Nuquí  704.583366    None          1          5
#
#                                           Restriccio  Depto     Shape_Leng  \
# 0  “No es apropiada su aplicación para la ubicaci...  Chocó  270334.189583
#
#      Shape_Area                                           geometry
# 0  7.045834e+08  POLYGON ((-8603781.515 669641.052, -8603774.53...

# %%
nuqui_hume.head()
# Out:
#    Nivel_Hume     Area_Ha  Fecha_Ingr Fecha_Reco     NOMAH  \
# 0           2  727.503672  2020-08-28       None  Pacifico
# 1           2    1.590278  2020-08-28       None  Pacifico
# 2           1    0.000721  2020-08-28       None  Pacifico
# 3           1    0.092073  2020-08-28       None  Pacifico
# 4           1    0.132748  2020-08-28       None  Pacifico
#
#                  NOMZH                             NOMSZH Grado_Tran  \
# 0  Pacífico - Directos  Directos Pacifico Frontera Panamá    Natural
# 1  Pacífico - Directos  Directos Pacifico Frontera Panamá    Natural
# 2  Pacífico - Directos  Directos Pacifico Frontera Panamá          -
# 3  Pacífico - Directos  Directos Pacifico Frontera Panamá          -
# 4  Pacífico - Directos  Directos Pacifico Frontera Panamá          -
#
#                                             geometry
# 0  POLYGON ((-8605258.980 664590.975, -8605258.92...
# 1  MULTIPOLYGON (((-8604027.708 661085.072, -8604...
# 2  MULTIPOLYGON (((-8601697.467 655698.379, -8601...
# 3  MULTIPOLYGON (((-8601376.298 655497.838, -8601...
# 4  MULTIPOLYGON (((-8601678.268 655772.275, -8601...

# %% [markdown]
# A continuación, se muestra la demarcación espacial de los humedales con ayuda del mapa de fondo.

# %%
ax = nuqui_area.boundary.plot(figsize=(5,5), edgecolor='k', alpha=0.25)
nuqui_hume.plot(ax=ax,cmap='winter',alpha=1,column='Grado_Tran',legend=True, legend_kwds={'loc': 'center left', 'fontsize':8})
ax.set_axis_off()
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron)

# %% [markdown]
# # Exploración de datos
# ---

# %% [markdown]
# La siguiente sentencia permite revisar el tipo de dato que almacena cada columna o atributo de la tabla de datos de los shapefiles importados.

# %%
nuqui_hume.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 448 entries, 0 to 447
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Nivel_Hume  448 non-null    int64
#  1   Area_Ha     448 non-null    float64
#  2   Fecha_Ingr  448 non-null    object
#  3   Fecha_Reco  0 non-null      object
#  4   NOMAH       448 non-null    object
#  5   NOMZH       448 non-null    object
#  6   NOMSZH      448 non-null    object
#  7   Grado_Tran  448 non-null    object
#  8   geometry    448 non-null    geometry
# dtypes: float64(1), geometry(1), int64(1), object(6)
# memory usage: 31.6+ KB

# %% [markdown]
# Teniendo en cuenta que la capa *nuqui_hume* tiene un campo/columna/atributo/variable en el que se tiene precalculada el área de cada humedal, se puede aplicar a esta columna el método *describe()* para que despliegue estadísticas univariadas de esta variable.

# %%
nuqui_hume.Area_Ha.describe().round(3)
# Out:
# count     448.000
# mean       22.781
# std        83.780
# min         0.000
# 25%         0.002
# 50%         0.530
# 75%         4.838
# max      1098.710
# Name: Area_Ha, dtype: float64

# %% [markdown]
# *GeoPandas* permite calcular las áreas de cada polígono de la capa de información y la entrega en metros cuadrados, pero este cálculo depende del sistema de coordenadas de referencia sobre el que esté proyectada la capa. Obsérvese la diferencia entre la información de la tabla y lo calculado por Geopandas, sobre el tamaño promedio de los humedales en Nuquí.

# %%
( nuqui_hume.Area_Ha.describe()[1]*10000 ).round(3)
# Out:
# 227812.247

# %%
nuqui_hume.area.mean().round(3)
# Out:
# 222498.009

# %% [markdown]
# La capa de humedales refiere a un grado de transición de estos ecosistemas. Dado que esta variable es categórica, se pueden contar el número de humedales por cada grado de transición por medio del método *value_counts()*.

# %%
nuqui_hume.Grado_Tran.value_counts()
# Out:
# Grado_Tran
# -                    291
# Transformado          91
# Natural               57
# Sin informacion e      9
# Name: count, dtype: int64

# %% [markdown]
# Dado que existen valores en la columna 'Grado_Tran' sin información, se remplazan todos estos valores sin información bajo una misma etiqueta y con la ayuda de el método *loc()*.

# %%
nuqui_hume.loc[nuqui_hume['Grado_Tran'] == '-', 'Grado_Tran'] = 'Sin info.'
nuqui_hume.loc[nuqui_hume['Grado_Tran'] == 'Sin informacion e', 'Grado_Tran'] = 'Sin info.'

# %% [markdown]
# Se verifica el cambio.

# %%
nuqui_hume.Grado_Tran.value_counts()
# Out:
# Grado_Tran
# Sin info.       300
# Transformado     91
# Natural          57
# Name: count, dtype: int64

# %% [markdown]
# Se asigna un color a cada etiqueta al declarar un objero tipo diccionario y se despliega nuevamente el mapa cloroplético de humedales por niveles de transformación.

# %%
color_dict = {'Natural':'#0f3c4c', 'Sin info.':'grey', 'Transformado':'#d3eaf2'}
ax = nuqui_area.boundary.plot(figsize=(5,5), edgecolor='k', alpha=0.25)
nuqui_hume.plot(ax=ax, column='Grado_Tran', cmap=mcolors.ListedColormap(list(color_dict.values())), legend=True, legend_kwds={'loc': 'center left'})
ax.set_axis_off()
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron)

# %% [markdown]
# A continuación, se explora la tabla de la capa de coberturas del municipio con ayuda del método *head()*.

# %%
nuqui_lulc.head(3)
# Out:
#    OBJECTID_1  OBJECTID APOYO  CAMBIO CONFIABILI                   INSUMO  \
# 0       86468     86527  None       1         Si  Landsat 1056 2010/08/24
# 1       86472     86531  None       4         Si  Landsat 1056 2010/08/24
# 2       86473     86532  None       1         Si  Landsat 1056 2010/08/24
#
#    CODIGO    AREA_HA                               LEYENDA3N  Shape_Leng  \
# 0     411  25.085846                 4.1.1. Zonas Pantanosas    0.022433
# 1     521   3.706121                 5.2.1. Lagunas costeras    0.020881
# 2     423  16.593968  4.2.3. Sedimentos expuestos en bajamar    0.031021
#
#    Shape_Le_1  Shape_Area  RULEID  \
# 0    0.022433    0.000020      44
# 1    0.020881    0.000003      54
# 2    0.031021    0.000014      49
#
#                                             geometry
# 0  POLYGON ((-8599862.902 635168.486, -8599848.89...
# 1  MULTIPOLYGON (((-8602305.780 636302.250, -8602...
# 2  POLYGON ((-8599690.559 645682.467, -8599690.56...

# %% [markdown]
# Se representa la capa de coberturas en un mapa. En el primer ejemplo, se utiliza una paleta de colores predeterminada y llamada *'gist_earth'*.

# %%
ax = nuqui_lulc.plot(figsize=(5,5), column='LEYENDA3N', legend=True, cmap='gist_earth', legend_kwds={'loc': 'center left', 'bbox_to_anchor':(1,0.5)})
ax.set_axis_off()
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron)

# %% [markdown]
# Para mejorar la asignación correspondiente de colores a las diferentes coberturas, se asigna un código hexadecimal de color a cada cobertura mediante el uso de un diccionario de Python, que en la siguiente celda se ha llamado *'color_dict'*.

# %%
color_dict = {'1.1.1. Tejido urbano continuo': '#5c5c5c',
              '2.3.1. Pastos limpios': '#acb35b',
              '2.3.3. Pastos enmalezados': '#63a14d',
              '2.4.3. Mosaico de cultivos, pastos y espacios naturales': '#afb45c',
              '2.4.5. Mosaico de cultivos con espacios naturales': '#72a551',
              '3.1.1. Bosque denso': '#449949',
              '3.1.3. Bosque fragmentado': '#9eb059',
              '3.2.1. Herbazal': '#98ab59',
              '3.2.3. Vegetacion secundaria o en transicion': '#9eb059',
              '3.3.1. Zonas arenosas naturales': '#d6b197',
              '3.3.2. Afloramientos rocosos': '#abafae',
              '4.1.1. Zonas Pantanosas': '#bfa464',
              '4.2.3. Sedimentos expuestos en bajamar': '#328476',
              '5.1.1. Rios (50 m)': '#122b77',
              '5.2.1. Lagunas costeras': '#215c7b',
              '5.2.2. Mares y oceanos': '#020151'}

ax = nuqui_lulc.boundary.plot(figsize=(5,5), edgecolor='k', alpha=0.05)
nuqui_lulc.plot(ax=ax, column='LEYENDA3N', cmap=mcolors.ListedColormap(list(color_dict.values())), legend=True, legend_kwds={'loc': 'center left', 'bbox_to_anchor':(1,0.5)})
ax.set_axis_off()
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron)

# %% [markdown]
# A continuación. el método *sum()* aplicado al área precalculada y disponoble dentro del *GeoDataFrame* de coberturas, permite calcular el total de área de cada cobertura en el municipio, luego de utilizar el método *groupby()*.

# %%
nuqui_lulc.groupby('LEYENDA3N').AREA_HA.sum().round(3)
# Out:
# LEYENDA3N
# 1.1.1. Tejido urbano continuo                                   19.754
# 2.3.1. Pastos limpios                                            7.600
# 2.3.3. Pastos enmalezados                                      141.599
# 2.4.3. Mosaico de cultivos, pastos y espacios naturales       2899.302
# 2.4.5. Mosaico de cultivos con espacios naturales             1724.887
# 3.1.1. Bosque denso                                        1608639.490
# 3.1.3. Bosque fragmentado                                    10813.752
# 3.2.1. Herbazal                                                156.655
# 3.2.3. Vegetacion secundaria o en transicion                  2271.439
# 3.3.1. Zonas arenosas naturales                                 37.193
# 3.3.2. Afloramientos rocosos                                    45.407
# 4.1.1. Zonas Pantanosas                                         25.086
# 4.2.3. Sedimentos expuestos en bajamar                          16.594
# 5.1.1. Rios (50 m)                                             611.110
# 5.2.1. Lagunas costeras                                        139.524
# 5.2.2. Mares y oceanos                                         157.080
# Name: AREA_HA, dtype: float64

# %% [markdown]
# Del mismo modo, se puede construir una expresión que calcule la proporción de área de cada cobertura en el municipio.

# %%
( nuqui_lulc.groupby('LEYENDA3N').AREA_HA.sum() / nuqui_lulc.AREA_HA.sum() ).round(3)
# Out:
# LEYENDA3N
# 1.1.1. Tejido urbano continuo                              0.000
# 2.3.1. Pastos limpios                                      0.000
# 2.3.3. Pastos enmalezados                                  0.000
# 2.4.3. Mosaico de cultivos, pastos y espacios naturales    0.002
# 2.4.5. Mosaico de cultivos con espacios naturales          0.001
# 3.1.1. Bosque denso                                        0.988
# 3.1.3. Bosque fragmentado                                  0.007
# 3.2.1. Herbazal                                            0.000
# 3.2.3. Vegetacion secundaria o en transicion               0.001
# 3.3.1. Zonas arenosas naturales                            0.000
# 3.3.2. Afloramientos rocosos                               0.000
# 4.1.1. Zonas Pantanosas                                    0.000
# 4.2.3. Sedimentos expuestos en bajamar                     0.000
# 5.1.1. Rios (50 m)                                         0.000
# 5.2.1. Lagunas costeras                                    0.000
# 5.2.2. Mares y oceanos                                     0.000
# Name: AREA_HA, dtype: float64

# %% [markdown]
# Tal y como se observaba en el anterior resumen, casi la totalidad del área de Nuquí se compone de *Bosque denso*. A continuación, se representa esta información en un diagrama de barras.

# %%
nuqui_lulc.groupby('LEYENDA3N').AREA_HA.sum().plot.barh()
# Out:
# <Axes: ylabel='LEYENDA3N'>

# %% [markdown]
# #Ejemplo de cruce de coberturas con edificios OSM
# ---

# %% [markdown]
# Se pudo observar anteriormente que el *GeoDataFrame* de la capa de los límites del municipio de Nuquí contiene solamente un elemento en su tabla. Al llamar a su dato de tipo *geometría*, se obseva que este es un polígono, mediante el uso del método *type()*.

# %%
type( nuqui_area.to_crs(epsg=4326).geometry[0] )
# Out:
# shapely.geometry.polygon.Polygon

# %% [markdown]
# A continuación, se utiliza este polígono de los límites de Nuquí para construir un mapa que muestra los edificios que se encuentran dentro de este polígono y que hacen parte de la información libre disponible en *OpenStreetMap*.

# %%
m = leafmap.Map(toolbar_control=False, layers_control=True)
m.add_osm_from_polygon(nuqui_area.to_crs(epsg=4326).geometry[0], tags = {'building': True} )
m
# Out:
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# La siguiente celda guarda los datos de edificios desplegados anteriormente en un GeodataFrame llamado *nuqui_osmb*.

# %%
nuqui_osmb = leafmap.osm_gdf_from_polygon(nuqui_area.to_crs(epsg=4326).geometry[0], tags = {'building': True} )
nuqui_osmb.info()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <class 'geopandas.geodataframe.GeoDataFrame'>
# MultiIndex: 437 entries, ('way', 546918776) to ('way', 1145160789)
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nodes            437 non-null    object
#  1   building         437 non-null    object
#  2   geometry         437 non-null    geometry
#  3   name             23 non-null     object
#  4   amenity          10 non-null     object
#  5   religion         2 non-null      object
#  6   aeroway          1 non-null      object
#  7   tourism          7 non-null      object
#  8   addr:postcode    1 non-null      object
#  9   addr:street      1 non-null      object
#  10  government       2 non-null      object
#  11  office           2 non-null      object
#  12  denomination     1 non-null      object
#  13  internet_access  1 non-null      object
#  14  shop             2 non-null      object
#  15  craft            1 non-null      object
#  16  information      1 non-null      object
#  17  addr:city        4 non-null      object
#  18  building:levels  4 non-null      object
#  19  height           4 non-null      object
#  20  source           196 non-null    object
#  21  ethnic           1 non-null      object
#  22  description      1 non-null      object
#  23  roof:colour      3 non-null      object
#  24  image            1 non-null      object
# dtypes: geometry(1), object(24)
# memory usage: 106.4+ KB

# %% [markdown]
# A continuación se muestra cómo se pueden filtrar los objetos de la capa de edificios, conservando solo aquellos que tienen dato en su campo *'name'*. Del mismo modo, se pueden filtrar los atributos/columnas de interés.

# %%
nuqui_osmb = nuqui_osmb.loc[nuqui_osmb['name'].notnull(), ['name','geometry']]
nuqui_osmb
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                     name  \
# element_type osmid
# way          570183748                        Biblioteca
#              570183750                           Iglesia
#              675282449               Estación de policía
#              675282451                          Nuquimar
#              675282453                        Arena Azul
#              675282493   Centro administrativo municipal
#              675282494                    Puerta del Sol
#              675282495                Biblioteca pública
#              675282496                   Pacífico Travel
#              677086207                Punto vive digital
#              677086208                           Marimar
#              677086209                            Tienda
#              677086210                       Delfín Real
#              677086211                              Pola
#              677086212                    IPS Comfachocó
#              677086216       Juzgado promiscuo municipal
#              677086220                        Farmacosta
#              677086221  Notaria única del circuito Nuquí
#              723774701                   Bar playa terco
#              854798117                Tienda y Panadería
#              998259928               Cabanas Playa Terco
#              998260433               Cabanas Playa Terco
#              998260434               Cabanas Playa Terco
#
#                                                                  geometry
# element_type osmid
# way          570183748  POLYGON ((-77.47488 5.59567, -77.47472 5.59564...
#              570183750  POLYGON ((-77.47467 5.59562, -77.47472 5.59544...
#              675282449  POLYGON ((-77.27103 5.70702, -77.27109 5.70715...
#              675282451  POLYGON ((-77.26421 5.71270, -77.26414 5.71279...
#              675282453  POLYGON ((-77.26356 5.71282, -77.26365 5.71288...
#              675282493  POLYGON ((-77.26741 5.70875, -77.26754 5.70890...
#              675282494  POLYGON ((-77.26579 5.71046, -77.26597 5.71065...
#              675282495  POLYGON ((-77.26737 5.70846, -77.26745 5.70834...
#              675282496  POLYGON ((-77.26608 5.70754, -77.26626 5.70765...
#              677086207  POLYGON ((-77.27023 5.70749, -77.27026 5.70756...
#              677086208  POLYGON ((-77.26720 5.70749, -77.26729 5.70767...
#              677086209  POLYGON ((-77.26677 5.70803, -77.26686 5.70818...
#              677086210  POLYGON ((-77.26609 5.70968, -77.26617 5.70976...
#              677086211  POLYGON ((-77.26620 5.70958, -77.26626 5.70963...
#              677086212  POLYGON ((-77.26727 5.70911, -77.26721 5.70916...
#              677086216  POLYGON ((-77.26741 5.70875, -77.26734 5.70865...
#              677086220  POLYGON ((-77.26647 5.70812, -77.26655 5.70817...
#              677086221  POLYGON ((-77.26621 5.70813, -77.26633 5.70821...
#              723774701  POLYGON ((-77.42885 5.61918, -77.42876 5.61910...
#              854798117  POLYGON ((-77.47451 5.59602, -77.47445 5.59615...
#              998259928  POLYGON ((-77.42872 5.61888, -77.42867 5.61893...
#              998260433  POLYGON ((-77.42867 5.61884, -77.42862 5.61889...
#              998260434  POLYGON ((-77.42863 5.61880, -77.42858 5.61885...

# %% [markdown]
# A continuación, se calcula un centroide por cada polígono que representa un edificio en la tabla filtrada obtenida anteriormente.

# %%
centroides = nuqui_osmb.to_crs(epsg=9377).geometry.centroid
centroides
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# element_type  osmid
# way           570183748    POINT (4504122.947 2178197.297)
#               570183750    POINT (4504140.517 2178185.457)
#               675282449    POINT (4526843.549 2190382.591)
#               675282451    POINT (4527608.463 2190996.296)
#               675282453    POINT (4527673.232 2191020.430)
#               675282493    POINT (4527248.777 2190579.863)
#               675282494    POINT (4527418.129 2190763.702)
#               675282495    POINT (4527232.124 2190528.923)
#               675282496    POINT (4527382.131 2190438.844)
#               677086207    POINT (4526933.702 2190430.050)
#               677086208    POINT (4527262.252 2190431.682)
#               677086209    POINT (4527311.819 2190489.163)
#               677086210    POINT (4527390.265 2190672.457)
#               677086211    POINT (4527376.510 2190657.092)
#               677086212    POINT (4527287.038 2190606.969)
#               677086216    POINT (4527254.702 2190561.807)
#               677086220    POINT (4527345.351 2190499.639)
#               677086221    POINT (4527370.235 2190498.605)
#               723774701    POINT (4509253.414 2180767.934)
#               854798117    POINT (4504165.576 2178250.569)
#               998259928    POINT (4509264.560 2180737.279)
#               998260433    POINT (4509269.499 2180732.642)
#               998260434    POINT (4509273.741 2180728.365)
# dtype: geometry

# %% [markdown]
# A continuación, se construye un GeoDataFrame en el que se toma el nombre de los edificios y se les relaciona la geometría de punto de sus centroides.

# %%
nuqui_osmb.crs
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
nuqui_osmb = gpd.GeoDataFrame({'nom_edif':nuqui_osmb.name, 'geometry':centroides}, crs='EPSG:9377').to_crs(epsg=3857)

# %% [markdown]
# Con la ayuda del método *sjoin()* (spatial join) se puede asociar la información de la capa de coberturas a los puntos de los edificios, por supuesto, dependiendo de la cobertura sobre la que se encuentren estos puntos.

# %%
nuqui_lulc.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
nuqui_osmb = nuqui_osmb.sjoin(nuqui_lulc[['LEYENDA3N','geometry']], how="inner", predicate='intersects')

# %% [markdown]
# Como se observa en las dos siguientes celdas, 12 edificios se encuentran dentro de la cobertura *Tejido urbano continuo* mientras que otros 6 se encuentran en la cobertura 'Mosaico de cultivos, pastos y espacios naturales'.

# %%
nuqui_osmb
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                 nom_edif  \
# element_type osmid
# way          570183748                        Biblioteca
#              570183750                           Iglesia
#              675282449               Estación de policía
#              675282493   Centro administrativo municipal
#              675282495                Biblioteca pública
#              677086207                Punto vive digital
#              677086208                           Marimar
#              677086209                            Tienda
#              677086210                       Delfín Real
#              677086211                              Pola
#              677086212                    IPS Comfachocó
#              677086216       Juzgado promiscuo municipal
#              677086220                        Farmacosta
#              677086221  Notaria única del circuito Nuquí
#              675282451                          Nuquimar
#              675282453                        Arena Azul
#              675282494                    Puerta del Sol
#              675282496                   Pacífico Travel
#
#                                                geometry  index_right  \
# element_type osmid
# way          570183748  POINT (-8624456.303 623894.516)           53
#              570183750  POINT (-8624438.599 623882.702)           53
#              675282449  POINT (-8601766.160 636367.062)            5
#              675282493  POINT (-8601361.207 636569.273)            5
#              675282495  POINT (-8601377.530 636517.718)            5
#              677086207  POINT (-8601676.095 636415.655)            5
#              677086208  POINT (-8601346.589 636419.764)            5
#              677086209  POINT (-8601297.304 636478.171)            5
#              677086210  POINT (-8601219.991 636663.820)            5
#              677086211  POINT (-8601233.672 636648.204)            5
#              677086212  POINT (-8601323.035 636596.927)            5
#              677086216  POINT (-8601355.130 636551.087)            5
#              677086220  POINT (-8601263.751 636488.999)            5
#              677086221  POINT (-8601238.786 636488.142)            5
#              675282451  POINT (-8601003.558 636992.419)           36
#              675282453  POINT (-8600938.777 637017.271)           36
#              675282494  POINT (-8601192.724 636756.154)           36
#              675282496  POINT (-8601226.411 636427.894)           36
#
#                                                                 LEYENDA3N
# element_type osmid
# way          570183748  2.4.3. Mosaico de cultivos, pastos y espacios ...
#              570183750  2.4.3. Mosaico de cultivos, pastos y espacios ...
#              675282449                      1.1.1. Tejido urbano continuo
#              675282493                      1.1.1. Tejido urbano continuo
#              675282495                      1.1.1. Tejido urbano continuo
#              677086207                      1.1.1. Tejido urbano continuo
#              677086208                      1.1.1. Tejido urbano continuo
#              677086209                      1.1.1. Tejido urbano continuo
#              677086210                      1.1.1. Tejido urbano continuo
#              677086211                      1.1.1. Tejido urbano continuo
#              677086212                      1.1.1. Tejido urbano continuo
#              677086216                      1.1.1. Tejido urbano continuo
#              677086220                      1.1.1. Tejido urbano continuo
#              677086221                      1.1.1. Tejido urbano continuo
#              675282451  2.4.3. Mosaico de cultivos, pastos y espacios ...
#              675282453  2.4.3. Mosaico de cultivos, pastos y espacios ...
#              675282494  2.4.3. Mosaico de cultivos, pastos y espacios ...
#              675282496  2.4.3. Mosaico de cultivos, pastos y espacios ...

# %%
nuqui_osmb.LEYENDA3N.value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# LEYENDA3N
# 1.1.1. Tejido urbano continuo                              12
# 2.4.3. Mosaico de cultivos, pastos y espacios naturales     6
# Name: count, dtype: int64

# %% [markdown]
# #Funciones geoespaciales usuales#
# ---

# %% [markdown]
# Se llaman los archivos a los cuales se les realizaran los calculos

# %%
centros_poblados_nacional = gpd.read_file( ubicacion_shps[1], encoding='utf-8' ) # centros poblados a nivel nacional
limite = gpd.read_file( ubicacion_shps[5], encoding='utf-8' ) #area_mpio_Nuqui
nuqui_hume = gpd.read_file( ubicacion_shps[0], encoding='utf-8' ) # Humedales
nuqui_lulc = gpd.read_file( ubicacion_shps[3], encoding='utf-8' ) #coberturas
nuqui_area = gpd.read_file( ubicacion_shps[4], encoding='utf-8' ) # Geometriia del municipio de Nuquii
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
centros_poblados_nacional.plot()
# Out:
# <Axes: >

# %% [markdown]
# #Filtrado de Campos y plot

# %%
#centros_poblados_nacional[centros_poblados_nacional.MPIO_CDPMP=="05001"]
centros_poblados_nacional[centros_poblados_nacional.CLAS_CCDGO=="1"]#.value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      DPTO_CCDGO MPIO_CCDGO MPIO_CDPMP CLAS_CCDGO CLAS_CCNCT  CLAS_NAREA  \
# 0            05        001      05001          1     050011  121.218883
# 2            05        002      05002          1     050021    1.238698
# 4            05        004      05004          1     050041    0.156826
# 6            05        021      05021          1     050211    0.402125
# 7            05        030      05030          1     050301    1.547309
# ...         ...        ...        ...        ...        ...         ...
# 2022         97        666      97666          1     976661    0.404142
# 2025         99        001      99001          1     990011    7.148390
# 2027         99        524      99524          1     995241    5.521237
# 2029         99        624      99624          1     996241    1.651102
# 2031         99        773      99773          1     997731    0.958364
#
#       CLAS_VGNC  Shape_Leng  Shape_Area  \
# 0          2021    1.220110    0.009898
# 2          2021    0.071662    0.000101
# 4          2021    0.026742    0.000013
# 6          2021    0.040012    0.000033
# 7          2021    0.089251    0.000126
# ...         ...         ...         ...
# 2022       2021    0.051420    0.000033
# 2025       2021    0.137001    0.000576
# 2027       2021    0.136921    0.000449
# 2029       2021    0.095972    0.000134
# 2031       2021    0.045571    0.000078
#
#                                                geometry
# 0     MULTIPOLYGON (((4719464.531 2241329.470, 47194...
# 2     POLYGON ((4730925.224 2199417.691, 4730924.582...
# 4     POLYGON ((4661499.225 2292283.373, 4661497.001...
# 6     POLYGON ((4763270.808 2263527.899, 4763347.895...
# 7     POLYGON ((4701556.432 2227009.814, 4701558.005...
# ...                                                 ...
# 2022  POLYGON ((5374772.501 1495798.778, 5374776.075...
# 2025  POLYGON ((5611434.253 2246493.400, 5611439.036...
# 2027  POLYGON ((5288403.564 2166343.015, 5288408.335...
# 2029  POLYGON ((5237574.385 2126949.199, 5237554.290...
# 2031  POLYGON ((5355686.160 2050581.717, 5355704.268...
#
# [1103 rows x 10 columns]

# %% [markdown]
# crear nuevo campo

# %%
centros_poblados_nacional.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   DPTO_CCDGO MPIO_CCDGO MPIO_CDPMP CLAS_CCDGO CLAS_CCNCT  CLAS_NAREA  \
# 0         05        001      05001          1     050011  121.218883
# 1         05        001      05001          2     050012   11.886295
# 2         05        002      05002          1     050021    1.238698
# 3         05        002      05002          2     050022    0.107741
# 4         05        004      05004          1     050041    0.156826
#
#    CLAS_VGNC  Shape_Leng  Shape_Area  \
# 0       2021    1.220110    0.009898
# 1       2021    1.047351    0.000971
# 2       2021    0.071662    0.000101
# 3       2021    0.042441    0.000009
# 4       2021    0.026742    0.000013
#
#                                             geometry
# 0  MULTIPOLYGON (((4719464.531 2241329.470, 47194...
# 1  MULTIPOLYGON (((4705294.769 2242236.907, 47053...
# 2  POLYGON ((4730925.224 2199417.691, 4730924.582...
# 3  MULTIPOLYGON (((4724079.456 2191914.516, 47240...
# 4  POLYGON ((4661499.225 2292283.373, 4661497.001...

# %%
centros_poblados_nacional['nwfield']=1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
del centros_poblados_nacional['nwfield']
#centros_poblados_nacional['nwfield']=range(1,len(centros_poblados_nacional)+1)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# nuevo campo con expresión

# %%
centros_poblados_nacional['nwfield']=sum(centros_poblados_nacional.Shape_Area)
centros_poblados_nacional[centros_poblados_nacional.MPIO_CDPMP=="05001"]
# Out:
#   DPTO_CCDGO MPIO_CCDGO MPIO_CDPMP CLAS_CCDGO CLAS_CCNCT  CLAS_NAREA  \
# 0         05        001      05001          1     050011  121.218883
# 1         05        001      05001          2     050012   11.886295
#
#    CLAS_VGNC  Shape_Leng  Shape_Area  \
# 0       2021    1.220110    0.009898
# 1       2021    1.047351    0.000971
#
#                                             geometry   nwfield
# 0  MULTIPOLYGON (((4719464.531 2241329.470, 47194...  0.421678
# 1  MULTIPOLYGON (((4705294.769 2242236.907, 47053...  0.421678

# %%
sum(centros_poblados_nacional.Shape_Area) #validar
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0.4216775596322273

# %% [markdown]
# Ejemplo 1: Extracción y corte de areas espécificas (CLIP)

# %%
centros_poblados_nacional.crs
# Out:
# <Projected CRS: PROJCS["MAGNA-SIRGAS_Origen-Nacional",GEOGCS["MAGN ...>
# Name: MAGNA-SIRGAS_Origen-Nacional
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Transverse Mercator
# Datum: Marco Geocentrico Nacional de Referencia
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
clip_centros_poblados_nuqui = gpd.clip(centros_poblados_nacional, nuqui_area.to_crs(epsg=9377), keep_geom_type=False)
# Out:
# <ipython-input-67-1df898218a8b>:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: PROJCS["MAGNA-SIRGAS_Origen-Nacional",GEOGCS["MAGN ...
# Right CRS: EPSG:9377
#
#   clip_centros_poblados_nuqui = gpd.clip(centros_poblados_nacional, nuqui_area.to_crs(epsg=9377), keep_geom_type=False)

# %%
nuqui_area = nuqui_area.to_crs(epsg=3857)
clip_centros_poblados_nuqui = clip_centros_poblados_nuqui.to_crs(epsg=3857)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ax = nuqui_area.boundary.plot(figsize=(5,5), edgecolor='k', alpha=0.25)
nuqui_area.plot(ax=ax, color='#eab676', alpha=1, edgecolor="#eeeee4")
clip_centros_poblados_nuqui.plot(ax=ax,color='#21130d', alpha=1,edgecolor="#21130d")
ax.set_axis_off()
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron)

# %% [markdown]
# Ejemplo 2: Extendemos un Contorno alrededor del area de estudio (BUFFER)

# %%
area_buffer_mpio = nuqui_area.buffer(40000)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
area_buffer_mpio
# Out:
# 0    POLYGON ((-8668947.753 621994.192, -8668747.87...
# dtype: geometry

# %%
ax = area_buffer_mpio.boundary.plot(figsize=(10,10), edgecolor='k', alpha=0)
area_buffer_mpio.plot(ax=ax, color='#21130d', alpha=0.3, edgecolor="#21130d")
ax.set_axis_off()
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ax = area_buffer_mpio.boundary.plot(figsize=(10,10), edgecolor='k', alpha=0)
nuqui_area.plot(ax=ax, color='#eab676', alpha=1, edgecolor="#eeeee4")
clip_centros_poblados_nuqui.plot(ax=ax,color='#21130d', alpha=1,edgecolor="#21130d")
ax.set_axis_off()
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Ejemplo 2: Se realiza intersección de capas y dissolvemos con base en un valor común

# %%
resguardos = gpd.read_file( ubicacion_shps[5], encoding='utf-8' )

# %%
resguardos.crs
# Out:
# <Projected CRS: PROJCS["MAGNA-SIRGAS_Origen-Nacional",GEOGCS["MAGN ...>
# Name: MAGNA-SIRGAS_Origen-Nacional
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Transverse Mercator
# Datum: Marco Geocentrico Nacional de Referencia
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
union_nuqui = gpd.overlay(resguardos, nuqui_hume.to_crs(epsg=9377), how='union')
union_nuqui.head()
# Out:
# <ipython-input-76-ce0bd3fe4d9e>:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: PROJCS["MAGNA-SIRGAS_Origen-Nacional",GEOGCS["MAGN ...
# Right CRS: EPSG:9377
#
#   union_nuqui = gpd.overlay(resguardos, nuqui_hume.to_crs(epsg=9377), how='union')
#    OBJECTID ID_RESGUAR  NOMBRE_RES                 TIPO_PROCE CEDULA_CAT  \
# 0     299.0      10326  Rio Pangui  LEGALIZACIÓN DECRETO 1071       None
# 1     299.0      10326  Rio Pangui  LEGALIZACIÓN DECRETO 1071       None
# 2     299.0      10326  Rio Pangui  LEGALIZACIÓN DECRETO 1071       None
# 3     299.0      10326  Rio Pangui  LEGALIZACIÓN DECRETO 1071       None
# 4     299.0      10326  Rio Pangui  LEGALIZACIÓN DECRETO 1071       None
#
#   MATRICULA_  TIPO_ACTO_ NUMERO_ACT  FECHA_ACTO  AREA_ACTO_  ... SHAPE_Area  \
# 0    186-910  RESOLUCIÓN       0088  1982-07-27      7870.0  ...    0.00539
# 1    186-910  RESOLUCIÓN       0088  1982-07-27      7870.0  ...    0.00539
# 2    186-910  RESOLUCIÓN       0088  1982-07-27      7870.0  ...    0.00539
# 3    186-910  RESOLUCIÓN       0088  1982-07-27      7870.0  ...    0.00539
# 4    186-910  RESOLUCIÓN       0088  1982-07-27      7870.0  ...    0.00539
#
#   Nivel_Hume   Area_Ha  Fecha_Ingr Fecha_Reco     NOMAH                NOMZH  \
# 0        1.0  0.000549  2020-08-28       None  Pacifico  Pacífico - Directos
# 1        1.0  0.591932  2020-08-28       None  Pacifico  Pacífico - Directos
# 2        1.0  1.133298  2020-08-28       None  Pacifico  Pacífico - Directos
# 3        1.0  8.663699  2020-08-28       None  Pacifico  Pacífico - Directos
# 4        1.0  0.000314  2020-08-28       None  Pacifico  Pacífico - Directos
#
#                               NOMSZH  Grado_Tran  \
# 0  Directos Pacifico Frontera Panamá           -
# 1  Directos Pacifico Frontera Panamá           -
# 2  Directos Pacifico Frontera Panamá           -
# 3  Directos Pacifico Frontera Panamá           -
# 4  Directos Pacifico Frontera Panamá           -
#
#                                             geometry
# 0  POLYGON Z ((4524917.317 2170684.957 0.000, 452...
# 1  MULTIPOLYGON Z (((4524854.257 2171223.905 0.00...
# 2  MULTIPOLYGON Z (((4524931.915 2170684.931 0.00...
# 3  MULTIPOLYGON Z (((4525084.768 2172406.373 0.00...
# 4  MULTIPOLYGON Z (((4524810.932 2172757.799 0.00...
#
# [5 rows x 31 columns]

# %%
interseccion_nuqui = gpd.overlay(resguardos, nuqui_hume.to_crs(epsg=9377), how='intersection')
interseccion_nuqui.head()
# Out:
# <ipython-input-77-dccc88f0f828>:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: PROJCS["MAGNA-SIRGAS_Origen-Nacional",GEOGCS["MAGN ...
# Right CRS: EPSG:9377
#
#   interseccion_nuqui = gpd.overlay(resguardos, nuqui_hume.to_crs(epsg=9377), how='intersection')
#    OBJECTID ID_RESGUAR  NOMBRE_RES                 TIPO_PROCE CEDULA_CAT  \
# 0       299      10326  Rio Pangui  LEGALIZACIÓN DECRETO 1071       None
# 1       299      10326  Rio Pangui  LEGALIZACIÓN DECRETO 1071       None
# 2       299      10326  Rio Pangui  LEGALIZACIÓN DECRETO 1071       None
# 3       299      10326  Rio Pangui  LEGALIZACIÓN DECRETO 1071       None
# 4       299      10326  Rio Pangui  LEGALIZACIÓN DECRETO 1071       None
#
#   MATRICULA_  TIPO_ACTO_ NUMERO_ACT  FECHA_ACTO  AREA_ACTO_  ... SHAPE_Area  \
# 0    186-910  RESOLUCIÓN       0088  1982-07-27      7870.0  ...    0.00539
# 1    186-910  RESOLUCIÓN       0088  1982-07-27      7870.0  ...    0.00539
# 2    186-910  RESOLUCIÓN       0088  1982-07-27      7870.0  ...    0.00539
# 3    186-910  RESOLUCIÓN       0088  1982-07-27      7870.0  ...    0.00539
# 4    186-910  RESOLUCIÓN       0088  1982-07-27      7870.0  ...    0.00539
#
#   Nivel_Hume   Area_Ha  Fecha_Ingr Fecha_Reco     NOMAH                NOMZH  \
# 0          1  0.000549  2020-08-28       None  Pacifico  Pacífico - Directos
# 1          1  0.591932  2020-08-28       None  Pacifico  Pacífico - Directos
# 2          1  1.133298  2020-08-28       None  Pacifico  Pacífico - Directos
# 3          1  8.663699  2020-08-28       None  Pacifico  Pacífico - Directos
# 4          1  0.000314  2020-08-28       None  Pacifico  Pacífico - Directos
#
#                               NOMSZH  Grado_Tran  \
# 0  Directos Pacifico Frontera Panamá           -
# 1  Directos Pacifico Frontera Panamá           -
# 2  Directos Pacifico Frontera Panamá           -
# 3  Directos Pacifico Frontera Panamá           -
# 4  Directos Pacifico Frontera Panamá           -
#
#                                             geometry
# 0  POLYGON Z ((4524917.317 2170684.957 0.000, 452...
# 1  MULTIPOLYGON Z (((4524854.257 2171223.905 0.00...
# 2  MULTIPOLYGON Z (((4524931.915 2170684.931 0.00...
# 3  MULTIPOLYGON Z (((4525084.768 2172406.373 0.00...
# 4  MULTIPOLYGON Z (((4524810.932 2172757.799 0.00...
#
# [5 rows x 31 columns]

# %% [markdown]
# Dissolve

# %%
union_nuqui['valor_comun'] = 1
dissolved_nuqui = union_nuqui.dissolve(by='valor_comun')

# %%
dissolved_nuqui.plot()
# Out:
# <Axes: >

# %% [markdown]
# Se exporta al directorio raiz sobre el que se encuentran los *shapefiles* descargados inicialmente.

# %%
dissolved_nuqui.to_file('/content/Nuqui_Manual_Python/dissolved_nuqui.shp')
# Out:
# <ipython-input-80-d40a73b44238>:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   dissolved_nuqui.to_file('/content/Nuqui_Manual_Python/dissolved_nuqui.shp')
# WARNING:fiona._env:Normalized/laundered field name: 'valor_comun' to 'valor_comu'

# %% [markdown]
# #Ejemplo 3: Se realiza rasterización con GDAL

# %%
dissolved_nuqui.head()
# Out:
#                                                       geometry  OBJECTID  \
# valor_comun
# 1            MULTIPOLYGON Z (((4504028.671 2174840.394 0.00...     299.0
#
#             ID_RESGUAR  NOMBRE_RES                 TIPO_PROCE CEDULA_CAT  \
# valor_comun
# 1                10326  Rio Pangui  LEGALIZACIÓN DECRETO 1071       None
#
#             MATRICULA_  TIPO_ACTO_ NUMERO_ACT  FECHA_ACTO  ...  SHAPE_Leng  \
# valor_comun                                                ...
# 1              186-910  RESOLUCIÓN       0088  1982-07-27  ...    0.442793
#
#             SHAPE_Area Nivel_Hume   Area_Ha  Fecha_Ingr Fecha_Reco     NOMAH  \
# valor_comun
# 1              0.00539        1.0  0.000549  2020-08-28       None  Pacifico
#
#                            NOMZH                             NOMSZH  \
# valor_comun
# 1            Pacífico - Directos  Directos Pacifico Frontera Panamá
#
#              Grado_Tran
# valor_comun
# 1                     -
#
# [1 rows x 31 columns]

# %%
# Define pixel_size and NoData value of new raster
#pixel_size = 12
#NoData_value = -9999
#RasterXSize
#RasterYSize

# Filename of input OGR file
train_fn = r'/content/Nuqui_Manual_Python/dissolved_nuqui.shp'
train_ds = ogr.Open(train_fn)

# Filename of the raster Tiff that will be created
raster_fn = r'/content/Nuqui_Manual_Python/dissolved_nuqui.tif'

# Open the data source and read in the extent
naip_fn = r'/content/Nuqui_Manual_Python/nuqui_mask.tif'
naip_ds = gdal.Open(naip_fn)

#tipo formato, proyección y extensión del raster
lyr = train_ds.GetLayer()
driver = gdal.GetDriverByName('GTiff') #https://gdal.org/drivers/raster/index.html
target_ds = driver.Create(raster_fn,naip_ds.RasterXSize,naip_ds.RasterYSize,1,gdal.GDT_UInt16) #https://gdal.org/api/gdaldriver_cpp.html#_CPPv4N10GDALDriver6CreateEPKciii12GDALDataType12CSLConstList
target_ds.SetGeoTransform(naip_ds.GetGeoTransform()) #https://gdal.org/tutorials/geotransforms_tut.html #https://gdal.org/tutorials/raster_api_tut.html
target_ds.SetProjection(naip_ds.GetProjection())
options = ['ATTRIBUTE=OBJECTID']

#Rasterizar y seleccionar numero de bandas
gdal.RasterizeLayer(target_ds, [1], lyr, options=options)

#Write data to band 1
band = target_ds.GetRasterBand(1)
band.SetNoDataValue(0)
band = None
target_ds = None

#para verificar valores antes de exportar archivo
#data=target_ds.GetRasterBand(1).ReadAsArray()
#print('min',data.min(),'max',data.max(),'mean',data.mean())

# %% [markdown]
# referencias funciones
# https://gdal.org/drivers/raster/index.html
# https://gdal.org/api/gdaldriver_cpp.html#_CPPv4N10GDALDriver6CreateEPKciii12GDALDataType12CSLConstList
# target_ds.SetGeoTransform(naip_ds.GetGeoTransform())
#
# https://gdal.org/user/raster_data_model.html

# %% [markdown]
# Tambien podemos generar array para seguir procesando la información en formato raster

# %%
# Define pixel_size and NoData value of new raster
#pixel_size = 12
NoData_value = -9999

# Filename of input OGR file
train_fn = r'/content/Nuqui_Manual_Python/dissolved_nuqui.shp'
train_ds = ogr.Open(train_fn)

# Filename of the raster Tiff that will be created
raster_fn = r'/content/Nuqui_Manual_Python/dissolved_nuqui.tif'

# Open the data source and read in the extent
naip_fn = r'/content/Nuqui_Manual_Python/nuqui_mask.tif'
naip_ds = gdal.Open(naip_fn)

#tipo formato, proyección y extensión del raster
lyr = train_ds.GetLayer()
driver = gdal.GetDriverByName('GTiff')
target_ds = driver.Create(raster_fn, naip_ds.RasterXSize, naip_ds.RasterYSize, 1, gdal.GDT_UInt16)
target_ds.SetGeoTransform(naip_ds.GetGeoTransform())
target_ds.SetProjection(naip_ds.GetProjection())
options = ['ATTRIBUTE=OBJECTID']

#Rasterizar y seleccionar numero de bandas
gdal.RasterizeLayer(target_ds, [1], lyr, options=options)

#Write data to band 1
#band = target_ds.GetRasterBand(1)
#band.SetNoDataValue(0)
#band=None
#target_ds=None

#para verificar valores antes de exportar archivo
data = target_ds.GetRasterBand(1).ReadAsArray()
print('min',data.min(),'max',data.max(),'mean',data.mean())
# Out:
# min 0 max 299 mean 49.137654571315956
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()

# %%
plt.figure(figsize=(5,5))
plt.subplot(1,1,1)
ax = plt.imshow( data, cmap='Accent_r')
plt.axis('off')
ax

# %% [markdown]
# #Ejemplo 4: Se puede explorar el comportamiento estadístico  del raster

# %%
unique, counts = np.unique(data.ravel(), return_counts=True)
counts = list(counts)
unique = [str(x) for x in list(unique)]

# %%
plt.barh(unique, counts)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# #Ejemplo 5: Se puede procesar el raster por ejemplo, Conversión del GeoTiff a booleano

# %%
data = target_ds.GetRasterBand(1).ReadAsArray()
print('min',data.min(),'max',data.max(),'mean',data.mean())
# Out:
# min 0 max 299 mean 49.137654571315956

# %%
bin_data=np.where((data>=np.max(data)),1,0)
print('min',bin_data.min(),'max',bin_data.max(),'mean',bin_data.mean())
# Out:
# min 0 max 1 mean 0.16433998184386606

# %%
plt.figure(figsize=(5,5))
plt.subplot(1,1,1)
ax = plt.imshow(bin_data, cmap='binary_r' ) #binary
plt.axis('off')
ax

# %% [markdown]
# #DESPEDIDA

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ![OIP (2).jpeg](data:image/jpeg;base64,...)
#
# >Cualquier pregunta:
# tatiana.davila@correounivalle.edu.co
# anibal.montero@igac.gov.co
